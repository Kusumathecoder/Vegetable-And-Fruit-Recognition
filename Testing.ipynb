# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusumathecoder/Vegetable-And-Fruit-Recognition/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cnn = tf.keras.models.load_model('/content/trained_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #Visualization and performing prediction on single image [link text](https://)

# %%
import cv2
image_path='/content/drive/MyDrive/Vegetable_and_fruits/test/sweetpotato/Image_1.jpg'
img=cv2.imread(image_path)
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image=tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr=tf.keras.preprocessing.image.img_to_array(image)
input_arr=np.array([input_arr])
predictions=cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
print(predictions[0])
print(max(predictions[0]))
# Out:
# [8.7530816e-17 1.0309136e-22 1.2773824e-28 2.3033520e-12 0.0000000e+00
#  2.8178706e-20 1.4523670e-17 2.4670792e-36 1.2697808e-18 1.9718743e-17
#  1.9693597e-36 0.0000000e+00 9.5025552e-29 7.1430166e-26 0.0000000e+00
#  2.1582891e-26 3.8523746e-38 2.4550674e-32 2.1405614e-34 1.7783358e-11
#  3.9216132e-18 1.2748206e-15 7.2509773e-15 4.9042997e-27 4.7680248e-29
#  1.0449935e-29 9.2200247e-31 3.3041530e-09 6.8306861e-37 1.9174851e-26
#  0.0000000e+00 4.1481802e-20 1.0000000e+00 4.7938704e-13 0.0000000e+00
#  7.7746835e-30]
# 1.0

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index=np.where(predictions[0]==max(predictions[0]))
print(result_index[0][0])
# Out:
# 32

# %%
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("its is a {}".format(test_set.class_names[result_index[0][0]]))
# Out:
# its is a sweetpotato
