# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusumathecoder/Vegetable-And-Fruit-Recognition/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cnn = tf.keras.models.load_model('/content/trained_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #Visualization and performing prediction on single image [link text](https://)

# %%
import cv2
image_path='/content/drive/MyDrive/Vegetable_and_fruits/test/apple/Image_1.jpg'
img=cv2.imread(image_path)
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image=tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr=tf.keras.preprocessing.image.img_to_array(image)
input_arr=np.array([input_arr])
predictions=cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step

# %%
print(predictions[0])
print(max(predictions[0]))
# Out:
# [1.0000000e+00 3.9955133e-26 2.5851935e-19 2.6836267e-19 7.3087697e-37
#  9.2979346e-10 8.4173884e-13 1.3381995e-29 5.2843421e-17 1.3824962e-30
#  1.9109380e-38 1.7126523e-24 4.2975349e-31 5.5031823e-29 6.4214331e-24
#  5.9186520e-26 3.9287566e-25 5.5966061e-30 4.4723983e-30 4.5633350e-25
#  8.2743171e-13 3.2039355e-21 5.6975671e-16 5.5669467e-22 0.0000000e+00
#  6.5223115e-30 4.3873412e-19 2.0883477e-24 2.1762633e-14 1.9161665e-36
#  6.3303221e-32 2.0722920e-33 6.6182152e-19 3.2389171e-16 1.5743002e-24
#  1.9557168e-16]
# 1.0

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index=np.where(predictions[0]==max(predictions[0]))
print(result_index[0][0])
# Out:
# 0

# %%
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("its is a {}".format(test_set.class_names[result_index[0][0]]))
# Out:
# its is a apple
